# %% [markdown]
# # Скрипт для отбора данных из датасета FMA для дальнейшей кластеризации
# https://github.com/mdeff/fma
# # Код кластеризация для данного датасета в `clustering_FMA.ipynb`

# %%
import pandas as pd

# %%
tracks = pd.read_csv(r'C:\Users\user\Downloads\fma_metadata\tracks.csv',index_col=0, header=[1])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28568\974950279.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   tracks = pd.read_csv(r'C:\Users\user\Downloads\fma_metadata\tracks.csv',index_col=0, header=[1])

# %%
tracks.shape
# Out:
# (106575, 52)

# %%
tracks
# Out:
#           comments         date_created        date_released engineer  \
# track_id       NaN                  NaN                  NaN      NaN
# 2              0.0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3              0.0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5              0.0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10             0.0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# ...            ...                  ...                  ...      ...
# 155316         0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155317         0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155318         0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155319         0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155320         0.0  2017-03-26 16:22:18  2017-03-26 00:00:00      NaN
#
#           favorites       id  \
# track_id        NaN      NaN
# 2               4.0      1.0
# 3               4.0      1.0
# ...

# %%
columnns = ['favorites','id', 'listens','tracks','comments.1','latitude','longitude','bit_rate','duration','interest']

# %%
tracks.reset_index(inplace=True)
tracks
# Out:
#            index  comments         date_created        date_released engineer  \
# 0       track_id       NaN                  NaN                  NaN      NaN
# 1              2       0.0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 2              3       0.0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3              5       0.0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 4             10       0.0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# ...          ...       ...                  ...                  ...      ...
# 106570    155316       0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 106571    155317       0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 106572    155318       0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 106573    155319       0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 106574    155320       0.0  2017-03-26 16:22:18  2017-03-26 00:00:00      NaN
#
# ...

# %%
tracks = tracks[columnns][1:]

# %%
tracks.shape
# Out:
# (106574, 10)

# %%
tracks = tracks.dropna(how='any')

# %%
tracks.shape
# Out:
# (44544, 10)

# %%
tracks = tracks.rename({'comments.1':'comments'}, axis='columns')
tracks
# Out:
#         favorites       id  listens  tracks  comments   latitude   longitude  \
# 1             4.0      1.0   6073.0     7.0       0.0  40.058324  -74.405661
# 2             4.0      1.0   6073.0     7.0       0.0  40.058324  -74.405661
# 3             4.0      1.0   6073.0     7.0       0.0  40.058324  -74.405661
# 5             2.0      4.0   2710.0    13.0       2.0  51.895927    0.891874
# 6             2.0      4.0   2710.0    13.0       2.0  51.895927    0.891874
# ...           ...      ...      ...     ...       ...        ...         ...
# 106380       -1.0     -1.0     -1.0    -1.0       0.0  45.512303  -73.554431
# 106381       -1.0     -1.0     -1.0    -1.0       0.0  45.512303  -73.554431
# 106382       -1.0     -1.0     -1.0    -1.0       7.0  46.053219    8.986100
# 106410        0.0  20610.0  31847.0     6.0       3.0  35.670479  139.740921
# 106520       -1.0     -1.0     -1.0    -1.0       2.0  52.152355    5.292970
#
#         bit_rate  duration  interest
# ...

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44544 entries, 1 to 106520
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   favorites  44544 non-null  float64
#  1   id         44544 non-null  float64
#  2   listens    44544 non-null  float64
#  3   tracks     44544 non-null  float64
#  4   comments   44544 non-null  float64
#  5   latitude   44544 non-null  float64
#  6   longitude  44544 non-null  float64
#  7   bit_rate   44544 non-null  float64
#  8   duration   44544 non-null  float64
#  9   interest   44544 non-null  float64
# dtypes: float64(10)
# memory usage: 3.7 MB

# %%
tracks.to_csv(r'D:\Artem\Magistrature\1_sem\intellg_systems_and_techno\labs\datasets\FMA\tracks.csv')
